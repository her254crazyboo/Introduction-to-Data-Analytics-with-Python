# %%
import pandas as pd

# %%
sex = pd.read_excel("sex data.xlsx")
sex
# Out:
#                              Child Mortality Estimates Unnamed: 1  \
# 0        Sex-specific under-five mortality rate (U5MR)        NaN
# 1    Estimates generated by the UN Inter-agency Gro...        NaN
# 2            downloaded from http://childmortality.org        NaN
# 3                           Last update: 13 March 2024        NaN
# 4                   Contact: childmortality@unicef.org        NaN
# ..                                                 ...        ...
# 607                                                ZMB     Zambia
# 608                                                ZMB     Zambia
# 609                                                ZWE   Zimbabwe
# 610                                                ZWE   Zimbabwe
# 611                                                ZWE   Zimbabwe
#
#              Unnamed: 2 Unnamed: 3                   Unnamed: 4  \
# 0                   NaN        NaN                          NaN
# ...
